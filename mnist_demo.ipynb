# %% [markdown]
# ## MNIST 测试案例

# %% [markdown]
# ### 1. 下载数据

# %%
from data.load import get_data_loader

train_datas = get_data_loader("./", is_train=True)
test_datas = get_data_loader("./", is_train=False)

# %% [markdown]
# ### 2. 配置模型

# %%
from models import CNN_2Ct

model = CNN_2Ct()

# %% [markdown]
# ### 3. 训练

# %%
from engine import train
train(model, train_datas, test_datas, epochs=2)

# %% [markdown]
# ### 4. 测试

# %%
from engine import test
test(model, test_datas, 2)
